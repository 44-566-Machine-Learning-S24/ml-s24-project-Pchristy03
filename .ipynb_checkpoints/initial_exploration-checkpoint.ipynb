# %%
import pandas as pd

dataframe = pd.read_csv("Online Retail.csv")

# %%
print(dataframe.keys())
print("***********************************")
print(dataframe.head())
print("***********************************")
dataframe.info()
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')
# ***********************************
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1  2010-12-01 08:26:00       3.39       17850  United Kingdom
# 2  2010-12-01 08:26:00       2.75       17850  United Kingdom
# 3  2010-12-01 08:26:00       3.39       17850  United Kingdom
# ...

# %%
print(dataframe["Description"].value_counts())
print(dataframe["Quantity"].value_counts())
print(dataframe["UnitPrice"].value_counts())
print(dataframe["Country"].value_counts())
print(dataframe["InvoiceDate"].value_counts())
# Out:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER     2369
# REGENCY CAKESTAND 3 TIER               2200
# JUMBO BAG RED RETROSPOT                2159
# PARTY BUNTING                          1727
# LUNCH BAG RED RETROSPOT                1638
#                                        ...
# Missing                                   1
# historic computer difference?....se       1
# DUSTY PINK CHRISTMAS TREE 30CM            1
# WRAP BLUE RUSSIAN FOLKART                 1
# PINK BERTIE MOBILE PHONE CHARM            1
# Name: count, Length: 4223, dtype: int64
# Quantity
#  1        148227
#  2         81829
#  12        61063
#  6         40868
#  4         38484
#            ...
# -472           1
# -161           1
# -1206          1
# -272           1
# -80995         1
# Name: count, Length: 722, dtype: int64
# UnitPrice
# 1.25      50496
# 1.65      38181
# 0.85      28497
# 2.95      27768
# 0.42      24533
#           ...
# 84.21         1
# 46.86         1
# 28.66         1
# ...

# %%
dataframe.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  541909.000000
# mean        9.552250       4.611114   15287.518434
# std       218.081158      96.759853    1484.746041
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   14367.000000
# 50%         3.000000       2.080000   15287.000000
# 75%        10.000000       4.130000   16255.000000
# max     80995.000000   38970.000000   18287.000000

# %%
import matplotlib.pyplot as plt

dataframe = dataframe[dataframe['UnitPrice'] >= 0]
dataframe = dataframe[dataframe['Quantity'] >= 0]
dataframe = dataframe[dataframe['UnitPrice'] <= 50]
dataframe = dataframe[dataframe['Quantity'] <= 100]

print(dataframe.info())

dataframe.hist(bins=30)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 525346 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    525346 non-null  object
#  1   StockCode    525346 non-null  object
#  2   Description  524809 non-null  object
#  3   Quantity     525346 non-null  int64
#  4   InvoiceDate  525346 non-null  object
#  5   UnitPrice    525346 non-null  float64
#  6   CustomerID   525346 non-null  int64
#  7   Country      525346 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 36.1+ MB
# None
# array([[<Axes: title={'center': 'Quantity'}>,
#         <Axes: title={'center': 'UnitPrice'}>],
#        [<Axes: title={'center': 'CustomerID'}>, <Axes: >]], dtype=object)

# %%
working_set = dataframe.copy()

# %%
from pandas.plotting import scatter_matrix

# working_set["Birthdate"] = pd.to_datetime(working_set["Birthdate"], format='%Y-%m-%d')
# working_set['birth_year'] = working_set['Birthdate'].dt.year

# working_set["Date"] = pd.to_datetime(working_set["Date"], format='%Y-%m-%d')
# working_set['trans_month'] = working_set['Date'].dt.month

# working_set['trans_week'] = working_set['Date'].dt.isocalendar().week

working_set["InvoiceDate"] = pd.to_datetime(working_set["InvoiceDate"], format='%Y-%m-%d %H:%M:%S')
working_set['trans_month'] = working_set['InvoiceDate'].dt.month
working_set['trans_week'] = working_set['InvoiceDate'].dt.isocalendar().week
working_set["trans_day"] = working_set['InvoiceDate'].dt.dayofyear

weekly_average = []
for i in range(1, 53):
    weekly_average.append(working_set[working_set["trans_week"]== i]["UnitPrice"].sum())

# for price in weekly_average:
#     weekly_average.append(working_set[working_set["trans_week"]== price]["UnitPrice"].mean())

# print(weekly_average)

working_set['total_cost'] = working_set['Quantity'] * working_set['UnitPrice']

working_set = working_set[working_set['total_cost'] <= 100]

# create average weekly costs
average_weekly_cost = []
for i in range(1, 53):
    average_weekly_cost.append(working_set[working_set["trans_week"]== i]["UnitPrice"].mean())

average_daily_cost = []
for i in range(1, 366):
    average_daily_cost.append(working_set[working_set["trans_day"]== i]["UnitPrice"].mean())

# for i in range(1, 52):
    
weekly_transactions = working_set.groupby('trans_week').size()

print(weekly_transactions)


# print(len(average_weekly_cost))
# print(len(average_daily_cost))
# print(average_daily_cost)

# working_set['total_weekly'] = 

# print(working_set)
# compare = ["Quantity", "trans_month", "total_cost"]
# scatter_matrix(working_set[compare])
# Out:
# trans_week
# 1      7256
# 2      8446
# 3      9031
# 4      7284
# 5      6672
# 6      5354
# 7      6712
# 8      7338
# 9      7038
# 10     7086
# 11     7783
# 12     8114
# 13     8330
# 14     7511
# 15     7109
# 16     7736
# 17     4595
# 18     7658
# 19     9718
# 20     9026
# 21     7052
# 22     6444
# 23     9022
# 24     7909
# 25     7894
# 26     6427
# 27    10204
# 28     8584
# 29     9290
# 30     8002
# 31     7542
# 32     7160
# 33     6701
# 34     7698
# 35     9247
# 36     9791
# 37     9944
# 38    12903
# 39    11669
# 40    13518
# 41    12690
# 42    13059
# 43    13873
# 44    16030
# 45    18484
# 46    20249
# 47    19285
# 48    27984
# 49    32867
# 50    10633
# 51     4317
# dtype: int64

# %%
# monthly_totals = []
# for i in range(1, 13):
#        monthly_totals.append(working_set[working_set["trans_month"]== i]["Transaction Amount"].sum())

# monthly_average_tran = []
# for i in range(1, 11):
#     monthly_average_tran.append(working_set[working_set["trans_month"]== i]["Transaction Amount"].mean())

# weekly_average = []
# for i in range(1, 52):
#     weekly_average.append(working_set[working_set["trans_week"]== i]["Transaction Amount"].mean())

# daily_average = []
# for i in range(1, 366):
#     daily_average.append(working_set[working_set["trans_day"]== i]["Transaction Amount"].mean())

# daily_sum = []
# for i in range(1, 366):
#     daily_sum.append(working_set[working_set["trans_day"]== i]["Transaction Amount"].sum())

# # print(monthly_totals)
# # print(monthly_average_tran)
# # print(weekly_average)
# print(average_daily_cost)

# working_set["trans_month"].value_counts()

# %%
import matplotlib.pyplot as plt
import numpy as np

#Filter by age first
# plt.scatter(x=working_set["price"], y=working_set["age"], marker="o", c="green")
# female_price = np.ma.masked_where(working_set["Gender"]==1, working_set["Transaction Amount"])
# male_price = np.ma.masked_where(working_set["Gender"]==0, working_set["Transaction Amount"])

# male_monthly_mean = working_set[working_set["Gender"]== 1].groupby('trans_month')["Transaction Amount"].mean()
# female_monthly_mean = working_set[working_set["Gender"]== 0].groupby('trans_month')["Transaction Amount"].mean()

# male_weekly_mean = working_set[working_set["Gender"]== 1].groupby('trans_week')["Transaction Amount"].mean()
# female_weekly_mean = working_set[working_set["Gender"]== 0].groupby('trans_week')["Transaction Amount"].mean()

# print(len(male_weekly_mean))
# print(len(female_weekly_mean))

plt.scatter(x=range(1,53), y=average_weekly_cost, marker="o", c="green")
plt.show()
plt.scatter(x=range(1,52), y=weekly_transactions, marker="o", c="green")
# plt.scatter(x=range(1,43), y=female_weekly_mean, marker="o", c="yellow")
# plt.scatter(x=range(1,11), y=male_monthly_mean, marker="X", c="blue")
# plt.scatter(x=range(1,11), y=female_monthly_mean, marker="X", c="red")
plt.show()

plt.scatter(x=range(1,366), y=average_daily_cost, marker="o", c="green")
